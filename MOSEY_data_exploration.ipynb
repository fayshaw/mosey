# %% [markdown]
# # Move On Safely EverYone (MOSEY)
# Exploratory Data Analysis for Streamlit app: https://mosey-score.streamlit.app/
#
# ### Contents
# * Load files from MassDOT: https://apps.impact.dot.state.ma.us/cdv/
# * Data exploration
# * Preliminary plots
#   * Crash data for cars and pedstrians
#   * Plots with latitude and longitude on x/y plane
# * OpenStreetMap
#   * Car crashes: 100 points
#   * Car crashes: 1000 points with crashes (blue), pedestrian crashes (red)
#   * Address with proximity box (gray) with near crashes

# %% [markdown]
# ## Load files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import geopandas
import requests

# %%
folder = 'data_sources/'
crash_file = 'export_2_5_2024_12_39_01.csv' # 2013-2023 Malden, Melrose, Medford, Saugus, Stoneham, Woburn

all_crash_df = pd.read_csv(folder + crash_file, skipfooter=3, engine='python',
    dtype={'year': 'Int32', 'speed_limit': 'Int32'})

# %% [markdown]
# ## Data exploration

# %%
all_crash_df.head()
# Out:
#    Crash Number City Town Name  Crash Date    Crash Severity Crash Status  \
# 0       1531131         MALDEN  01/06/2003      Not Reported       Closed
# 1       1534486         MALDEN  01/01/2003      Not Reported       Closed
# 2       1534489         MALDEN  01/02/2003      Not Reported       Closed
# 3       1534497         MALDEN  01/02/2003  Non-fatal injury       Closed
# 4       1534501         MALDEN  01/02/2003  Non-fatal injury       Closed
#
#   Crash Time  Crash Year           Max Injury Severity Reported  \
# 0    1:30 PM        2003                           Not reported
# 1    4:00 AM        2003                           Not reported
# 2    7:00 AM        2003                           Not reported
# 3    4:10 AM        2003            Non-fatal injury - Possible
# 4    2:30 PM        2003  Non-fatal injury - Non-incapacitating
#
#    Number of Vehicles Police Agency Type  ... Terrain-linked RD  \
# 0                   1       Local police  ...               NaN
# 1                   2       Local police  ...             Level
# 2                   2       Local police  ...             Level
# 3                   3       Local police  ...             Level
# 4                   2       Local police  ...             Level
#
#                        Urban Location Type-linked RD  \
# 0                                                NaN
# 1  Not applicable (i.e., not a principal arterial...
# 2  High density business/commercial center (exclu...
# 3  High density residential (5,000 or more person...
# 4                             Low density commercial
#
#   AADT Derivation-linked RD AADT Station Number-linked RD  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#   Opposing Direction Speed Limit-linked RD  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Undivided Left Shoulder Type-linked RD  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Undivided Left Shoulder Width-linked RD Truck Exclusion Type-linked RD  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
#
#   Truck Exclusion Time-linked RD Federal Functional Classification-linked RD
# 0                            NaN                                         NaN
# 1                            NaN                  Principal Arterial - Other
# 2                            NaN                  Principal Arterial - Other
# 3                            NaN                              Minor Arterial
# 4                            NaN                  Principal Arterial - Other
#
# [5 rows x 123 columns]

# %%
all_crash_df.describe()
# Out:
#        Crash Number    Crash Year  Number of Vehicles  MassDOT District  \
# count  9.743100e+04  97431.000000        97431.000000           97431.0
# mean   3.384012e+06   2012.406288            1.931336               4.0
# std    1.241400e+06      6.272886            0.625690               0.0
# min    1.531131e+06   2003.000000            0.000000               4.0
# 25%    2.208633e+06   2007.000000            2.000000               4.0
# 50%    3.393844e+06   2012.000000            2.000000               4.0
# 75%    4.551954e+06   2018.000000            2.000000               4.0
# max    5.355843e+06   2023.000000           14.000000               4.0
#
#        Total Fatalities  Total Non-Fatal Injuries   Speed Limit  \
# count      97431.000000              97431.000000  51369.000000
# mean           0.002084                  0.328499     35.627363
# std            0.047365                  0.668357     13.852986
# min            0.000000                  0.000000      1.000000
# 25%            0.000000                  0.000000     25.000000
# 50%            0.000000                  0.000000     30.000000
# 75%            0.000000                  0.000000     45.000000
# max            3.000000                 13.000000    330.000000
#
#        Vulnerable User Sequence of Events (All Persons)  \
# count                                               0.0
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#        Vulnerable User Distracted By (All Persons)  \
# count                                          0.0
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        Vulnerable User Traffic Control Type (All persons)  ...  \
# count                                                0.0   ...
# mean                                                 NaN   ...
# std                                                  NaN   ...
# min                                                  NaN   ...
# 25%                                                  NaN   ...
# 50%                                                  NaN   ...
# 75%                                                  NaN   ...
# max                                                  NaN   ...
#
#        Surface Width-linked RD  Right Shoulder Width-linked RD  \
# count             86823.000000                    86634.000000
# mean                 32.772238                        1.960096
# std                  10.384174                        3.858971
# min                   0.000000                        0.000000
# 25%                  25.000000                        0.000000
# 50%                  32.000000                        0.000000
# 75%                  41.000000                        2.000000
# max                  80.000000                       24.000000
#
#        Number of Travel Lanes-linked RD  \
# count                      86883.000000
# mean                           2.283266
# std                            0.800482
# min                            0.000000
# 25%                            2.000000
# 50%                            2.000000
# 75%                            2.000000
# max                            4.000000
#
#        Number of Opposing Travel Lanes-linked RD  Median Width-linked RD  \
# count                               82808.000000            39948.000000
# mean                                    0.663764               11.812782
# std                                     1.331542               33.035586
# min                                     0.000000                0.000000
# 25%                                     0.000000                0.000000
# 50%                                     0.000000                5.000000
# 75%                                     0.000000               16.000000
# max                                     4.000000              450.000000
#
#        Number of Peak Hour Lanes-linked RD  Speed Limit-linked RD  \
# count                         13928.000000           35294.000000
# mean                              3.473004              45.804329
# std                               0.900039              21.701200
# min                               1.000000               0.000000
# 25%                               3.000000              30.000000
# 50%                               4.000000              35.000000
# 75%                               4.000000              55.000000
# max                               5.000000              99.000000
#
#        AADT Station Number-linked RD  \
# count                    1498.000000
# mean                     5247.884513
# std                      2489.806823
# min                        14.000000
# 25%                      4159.000000
# 50%                      5103.000000
# 75%                      5693.000000
# max                     21045.000000
#
#        Opposing Direction Speed Limit-linked RD  \
# count                              16757.000000
# mean                                  30.640449
# std                                   35.700009
# min                                    0.000000
# 25%                                    0.000000
# 50%                                   25.000000
# 75%                                   35.000000
# max                                   99.000000
#
#        Undivided Left Shoulder Width-linked RD
# count                             20174.000000
# mean                                  0.176713
# std                                   1.034454
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   8.000000
#
# [8 rows x 38 columns]

# %%
crash_cols = ['Crash Number', 'City Town Name', 'Crash Date', 'Crash Severity', 'Crash Time', 'Crash Year',
       'Max Injury Severity Reported', 'Number of Vehicles', 'First Harmful Event',
       'Is Geocoded', 'Light Conditions', 'Manner of Collision', 'Road Surface Condition', 
       'Total Fatalities', 'Total Non-Fatal Injuries', 'Weather Conditions',
       'Most Harmful Event (All Vehicles)', 'Speed Limit', 'Traffic Control Device Function',
       'Latitude', 'Longitude']

# %%
all_malden_df = all_crash_df[all_crash_df['City Town Name'] == 'MALDEN'][crash_cols]

malden_df = all_malden_df[all_malden_df['Crash Year'] >= 2013]
malden_df['Crash Year'].value_counts().sort_index()
# Out:
# Crash Year
# 2013     816
# 2014     529
# 2015     764
# 2016     945
# 2017    1014
# 2018     976
# 2019     946
# 2020     668
# 2021     803
# 2022     948
# 2023     894
# Name: count, dtype: int64

# %%
crash_count = pd.DataFrame()
crash_count['Crashes'] = pd.DataFrame(malden_df['Crash Year'].value_counts().sort_index())
crash_count
# Out:
#             Crashes
# Crash Year
# 2013            816
# 2014            529
# 2015            764
# 2016            945
# 2017           1014
# 2018            976
# 2019            946
# 2020            668
# 2021            803
# 2022            948
# 2023            894

# %%
ped_crash = malden_df[malden_df['First Harmful Event'] == 'Collision with pedestrian']
ped_crash
# Out:
#        Crash Number City Town Name  Crash Date    Crash Severity Crash Time  \
# 47674       3335916         MALDEN  01/11/2013  Non-fatal injury    6:55 AM
# 47839       3352304         MALDEN  02/06/2013  Non-fatal injury    5:05 PM
# 52715       3755858         MALDEN  01/24/2013  Non-fatal injury    7:54 PM
# 52723       3755867         MALDEN  01/31/2013  Non-fatal injury    7:34 AM
# 52798       3756004         MALDEN  01/02/2013  Non-fatal injury    5:30 PM
# ...             ...            ...         ...               ...        ...
# 97317       5355688         MALDEN  11/27/2023  Non-fatal injury   12:15 AM
# 97342       5355736         MALDEN  10/11/2023  Non-fatal injury   11:20 PM
# 97362       5355759         MALDEN  12/01/2023  Non-fatal injury    6:25 PM
# 97367       5355764         MALDEN  12/08/2023  Non-fatal injury    6:05 PM
# 97374       5355771         MALDEN  12/01/2023  Non-fatal injury    8:40 PM
#
#        Crash Year           Max Injury Severity Reported  Number of Vehicles  \
# 47674        2013  Non-fatal injury - Non-incapacitating                   1
# 47839        2013  Non-fatal injury - Non-incapacitating                   1
# 52715        2013  Non-fatal injury - Non-incapacitating                   1
# 52723        2013            Non-fatal injury - Possible                   1
# 52798        2013            Non-fatal injury - Possible                   1
# ...           ...                                    ...                 ...
# 97317        2023             Suspected Minor Injury (B)                   1
# 97342        2023                    Possible Injury (C)                   1
# 97362        2023             Suspected Minor Injury (B)                   1
# 97367        2023             Suspected Minor Injury (B)                   1
# 97374        2023           Suspected Serious Injury (A)                   1
#
#              First Harmful Event Is Geocoded  ...   Manner of Collision  \
# 47674  Collision with pedestrian         Yes  ...  Single vehicle crash
# 47839  Collision with pedestrian         Yes  ...               Head-on
# 52715  Collision with pedestrian         Yes  ...  Single vehicle crash
# 52723  Collision with pedestrian         Yes  ...  Single vehicle crash
# 52798  Collision with pedestrian         Yes  ...               Head-on
# ...                          ...         ...  ...                   ...
# 97317  Collision with pedestrian         Yes  ...  Single vehicle crash
# 97342  Collision with pedestrian         Yes  ...               Head-on
# 97362  Collision with pedestrian         Yes  ...               Head-on
# 97367  Collision with pedestrian         Yes  ...  Single vehicle crash
# 97374  Collision with pedestrian         Yes  ...  Single vehicle crash
#
#       Road Surface Condition Total Fatalities  Total Non-Fatal Injuries  \
# 47674                    Dry                0                         1
# 47839                    Dry                0                         1
# 52715                    Dry                0                         1
# 52723                    Wet                0                         1
# 52798                    Dry                0                         2
# ...                      ...              ...                       ...
# 97317                    Wet                0                         1
# 97342                    Dry                0                         1
# 97362                    Wet                0                         1
# 97367                    Dry                0                         1
# 97374                    Wet                0                         1
#
#        Weather Conditions Most Harmful Event (All Vehicles) Speed Limit  \
# 47674               Clear    V1:(Collision with pedestrian)        25.0
# 47839               Clear    V1:(Collision with pedestrian)        30.0
# 52715               Clear    V1:(Collision with pedestrian)         NaN
# 52723                Rain    V1:(Collision with pedestrian)         NaN
# 52798               Clear    V1:(Collision with pedestrian)         NaN
# ...                   ...                               ...         ...
# 97317         Cloudy/Rain    V1:(Collision with pedestrian)        25.0
# 97342               Clear    V1:(Collision with pedestrian)        25.0
# 97362           Rain/Rain    V1:(Collision with pedestrian)        20.0
# 97367               Clear    V1:(Collision with pedestrian)        25.0
# 97374                Rain    V1:(Collision with pedestrian)        25.0
#
#        Traffic Control Device Function   Latitude  Longitude
# 47674                     Not reported  42.426208 -71.087085
# 47839          Yes, device functioning  42.425218 -71.087165
# 52715          Yes, device functioning  42.423461 -71.072193
# 52723                     Not reported  42.431111 -71.054727
# 52798       No, device not functioning  42.420910 -71.057071
# ...                                ...        ...        ...
# 97317                     Not reported  42.432112 -71.029692
# 97342          Yes, device functioning  42.425852 -71.061799
# 97362                     Not reported  42.433921 -71.041909
# 97367          Yes, device functioning  42.421737 -71.058702
# 97374                     Not reported  42.426989 -71.041417
#
# [389 rows x 21 columns]

# %%
ped_count = pd.DataFrame()
ped_count['Crashes'] = pd.DataFrame(ped_crash['Crash Year'].value_counts().sort_index())
ped_count.head()
# Out:
#             Crashes
# Crash Year
# 2013             30
# 2014             17
# 2015             18
# 2016             51
# 2017             56

# %% [markdown]
# ## Preliminary plots

# %%
from matplotlib.ticker import FormatStrFormatter
x = np.linspace(2013, 2023, 11)

fig, ax = plt.subplots(figsize=(8, 3))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
plt.plot(x, crash_count, 'o-')
ax.set_xlabel('Years')
ax.set_ylabel('Crashes') 
ax.set_title('Car Crashes in Malden')
# Out:
# Text(0.5, 1.0, 'Car Crashes in Malden')

# %%
ped_fatal = malden_df[(malden_df['First Harmful Event'] == 'Collision with pedestrian') & (malden_df['Crash Severity'] == 'Fatal injury')]     
ped_fatal_count = pd.DataFrame(ped_fatal['Crash Year'].value_counts().sort_index())
ped_fatal.head()
# Out:
#        Crash Number City Town Name  Crash Date Crash Severity Crash Time  \
# 52807       3756013         MALDEN  01/09/2013   Fatal injury    6:37 PM
# 53943       3975673         MALDEN  12/26/2013   Fatal injury    6:13 AM
# 61846       4180596         MALDEN  12/27/2015   Fatal injury    7:18 PM
# 63085       4228771         MALDEN  01/04/2016   Fatal injury    6:19 PM
# 65324       4331187         MALDEN  12/22/2016   Fatal injury    7:35 PM
#
#        Crash Year Max Injury Severity Reported  Number of Vehicles  \
# 52807        2013             Fatal injury (K)                   1
# 53943        2013             Fatal injury (K)                   1
# 61846        2015             Fatal injury (K)                   1
# 63085        2016             Fatal injury (K)                   1
# 65324        2016             Fatal injury (K)                   1
#
#              First Harmful Event Is Geocoded  ...   Manner of Collision  \
# 52807  Collision with pedestrian         Yes  ...                 Angle
# 53943  Collision with pedestrian         Yes  ...  Single vehicle crash
# 61846  Collision with pedestrian         Yes  ...               Unknown
# 63085  Collision with pedestrian         Yes  ...  Single vehicle crash
# 65324  Collision with pedestrian         Yes  ...  Single vehicle crash
#
#       Road Surface Condition Total Fatalities  Total Non-Fatal Injuries  \
# 52807                    Wet                1                         1
# 53943                    Dry                1                         0
# 61846                    Wet                1                         0
# 63085                    Dry                1                         0
# 65324                    Wet                1                         0
#
#        Weather Conditions Most Harmful Event (All Vehicles) Speed Limit  \
# 52807              Cloudy    V1:(Collision with pedestrian)         NaN
# 53943               Clear    V1:(Collision with pedestrian)        35.0
# 61846           Rain/Rain                               NaN         NaN
# 63085               Clear    V1:(Collision with pedestrian)         NaN
# 65324               Clear    V1:(Collision with pedestrian)        25.0
#
#        Traffic Control Device Function   Latitude  Longitude
# 52807          Yes, device functioning  42.423969 -71.042565
# 53943                     Not reported  42.425569 -71.041958
# 61846                     Not reported  42.425492 -71.085935
# 63085                     Not reported  42.428460 -71.063131
# 65324                     Not reported  42.437425 -71.079719
#
# [5 rows x 21 columns]

# %%
ped_df = pd.DataFrame()
ped_df['crash_count'] = crash_count['Crashes']
ped_df['ped_crashes'] = ped_crash['Crash Year'].value_counts()
ped_df['ped_fatal'] = ped_fatal_count

ped_df = ped_df.fillna(0)
ped_df
# Out:
#             crash_count  ped_crashes  ped_fatal
# Crash Year
# 2013                816           30        2.0
# 2014                529           17        0.0
# 2015                764           18        1.0
# 2016                945           51        2.0
# 2017               1014           56        1.0
# 2018                976           60        0.0
# 2019                946           47        0.0
# 2020                668           27        1.0
# 2021                803           23        1.0
# 2022                948           27        0.0
# 2023                894           33        0.0

# %%
# Car crash / pedestrian crash data
from matplotlib.ticker import FormatStrFormatter
x = np.linspace(2013, 2023, 11)

fig, axes = plt.subplots(2, 1)
axes[0].plot(x, ped_df['crash_count'], 'o-', label='car crashes')

axes[0].set_ylabel('Car crashes')
custom_y_ticks = [0, 500, 1000, 1500, 2000]
axes[0].set_yticks(custom_y_ticks)
axes[0].xaxis.set_major_formatter(FormatStrFormatter('%d'))

axes[1].plot(x, ped_df['ped_crashes'], 'o-', color='orange', label='pedestrian crashes')
axes[1].set_ylabel('Pedestrian Crashes')
axes[1].xaxis.set_major_formatter(FormatStrFormatter('%d'))

# Adjust spacing between subplots to avoid overlapping titles and labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
from matplotlib.ticker import FormatStrFormatter
x = np.linspace(2013, 2023, 11)

fig, ax = plt.subplots(figsize=(8, 3))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
plt.plot(x, crash_count, 'o-', label='car crashes')
plt.plot(ped_count, 'o-', color='orange', label='crashes with pedestrians')
plt.plot(ped_fatal_count, 'x-', color='red', label='fatal crashes with pedestrians')
ax.legend(loc='upper right')

ax.set_xlabel('Years')
ax.set_ylabel('Crashes') 
ax.set_title('Crashes with Pedestrians')
# Out:
# Text(0.5, 1.0, 'Crashes with Pedestrians')

# %% [markdown]
# ## Latitude and Longitude plots

# %%
# functions for getting address and lat/lon box
def load_data():    
    folder = 'data_sources/'
    crash_file =  'export_2_5_2024_12_39_01.csv' # 2003-2023
    crash_df = pd.read_csv(folder + crash_file, skipfooter=3, engine='python',
                    dtype={'year': 'Int32', 'speed_limit': 'Int32'})
    return crash_df

def geocode(address): # need some sort of try/except if the address doesn't work?
    params = { 'format'        :'json', 
               'addressdetails': 1, 
               'q'             : address}
    headers = {'user-agent'    : 'TDI' }
    geo_data = requests.get('http://nominatim.openstreetmap.org/search', params=params, headers=headers)    
    return geo_data

def get_addr_str(addr_dict):  # for naming files
    num = addr_dict['house_number']    
    new_road = re.sub(" ", "_", addr_dict['road'])
    addr_str = num + '_' + new_road
    return addr_str

def find_box(lat, lon):    
    lat_conv = 0.000000274    #lat: 1 ft = 0.000000274 deg
    lon_conv = 0.000000347    #lon: 1 ft = 0.000000347 deg
    delta = 1000 # feet
    d_lat = delta * lat_conv
    d_lon = delta * lon_conv    
    return(lat-d_lat, lat+d_lat, lon-d_lon, lon+d_lon)

# other names: crash zone, bounding box, search quadrant
def get_zone_df(lat_0, lon_0, crash_df):
    min_lat, max_lat, min_lon, max_lon = find_box(lat_0, lon_0)   
    zone_df = crash_df[crash_df['Latitude'].between(min_lat, max_lat) & crash_df['Longitude'].between(min_lon, max_lon)]
    return zone_df
    
def get_geo_points(lat_0, lon_0, zone_df):
    # Create point geometries
    geo_zone_raw = geopandas.points_from_xy(zone_df['Latitude'], zone_df['Longitude'])
    geo_zone_raw_df = geopandas.GeoDataFrame(
        zone_df[['Crash Year', 'Longitude', 'Latitude', 'First Harmful Event']], geometry=geo_zone_raw)
    
    # Drop empty
    geo_zone_df = geo_zone_raw_df.loc[~geo_zone_raw_df.geometry.is_empty]
    geo_zone = geopandas.points_from_xy(geo_zone_raw_df['Latitude'], geo_zone_df['Longitude'])
    
    # Create a geometry list from the GeoDataFrame
    geo_zone_list = [[point.x, point.y] for point in geo_zone]
    return geo_zone_df, geo_zone_list

def crash_count(zone_df, thresh):
    zone_df = zone_df[zone_df['Crash Year'] > thresh]
    return zone_df.shape[0]

# %%
# app script
address = "442 Main Street Malden MA 02148" # user input
#address = '287 Washington St, Malden, MA 02148'

crash_df = load_data()                      # always the same

# user input
data = geocode(address).json()              # get lon / lat  <--- need to check if valid

# address check
# address to string for local saving

# make calcuations - find box
lat_0 = float(data[0]['lat'])            
lon_0 = float(data[0]['lon'])
min_lat, max_lat, min_lon, max_lon = find_box(lat_0, lon_0)

# get list of points
zone_df = get_zone_df(lat_0, lon_0, crash_df);

# get score
crash_counts_all = crash_count(zone_df, 2002)
crash_counts_post_2018 = crash_count(zone_df, 2018)

# make plot and other visualizations
# get points
geo_zone_df, geo_zone_list = get_geo_points(lat_0, lon_0, zone_df)

# init map 
m = folium.Map(location=[lat_0, lon_0], tiles="OpenStreetMap", zoom_start=18, 
               zoom_control=False, scrollWheelZoom=False, dragging=False)
m.add_child(
    folium.Marker(
        location = [lat_0, lon_0], popup='City Center', icon=folium.Icon(color='blue')        
    ))

# plot points
for ind, val in enumerate(geo_zone_list):
    folium.CircleMarker(location=geo_zone_list[ind], radius=2, weight=6, color='blue').add_to(m) # all pts
                    
# Create a rectangle (bounding box) on the map
folium.Rectangle(
    bounds=[(min_lat, min_lon), (max_lat, max_lon)],
    color='gray',
    fill=True,
    fill_color='gray',
    fill_opacity=0.2
).add_to(m)
    
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d9ae07eb48af1fb39499303153cbfca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d9ae07eb48af1fb39499303153cbfca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d9ae07eb48af1fb39499303153cbfca = L.map(
#                 &quot;map_0d9ae07eb48af1fb39499303153cbfca&quot;,
#                 {
#                     center: [42.4271186, -71.0671071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: false,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86462915c049b953b56ce6c2a2d42a09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_86462915c049b953b56ce6c2a2d42a09.addTo(map_0d9ae07eb48af1fb39499303153cbfca);
#
#
#             var marker_c3379cce750136abf4c7a1fc33f14148 = L.marker(
#                 [42.4271186, -71.0671071],
#                 {}
#             ).addTo(map_0d9ae07eb48af1fb39499303153cbfca);
#
#
#             var icon_8b345f8568885ae6ce3b8927c63c96b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3379cce750136abf4c7a1fc33f14148.setIcon(icon_8b345f8568885ae6ce3b8927c63c96b4);
#
#
#         var popup_b02fb486000a2a7d49ad100a681acb11 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b38b91e7ee2c8b92c728385495da0d9 = $(`&lt;div id=&quot;html_3b38b91e7ee2c8b92c728385495da0d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City Center&lt;/div&gt;`)[0];
#                 popup_b02fb486000a2a7d49ad100a681acb11.setContent(html_3b38b91e7ee2c8b92c728385495da0d9);
#
#
#
#         marker_c3379cce750136abf4c7a1fc33f14148.bindPopup(popup_b02fb486000a2a7d49ad100a681acb11)
#         ;
#
#
#
#
#             var circle_marker_7cd790bd066f9a0772fa085046d901f6 = L.circleMarker(
#                 [42.4272679, -71.06694234],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_0d9ae07eb48af1fb39499303153cbfca);
#
#
#             var circle_marker_a0d2891cac64631a8363bb7dd632bcd1 = L.circleMarker(
#                 [42.42698818, -71.06677413],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_0d9ae07eb48af1fb39499303153cbfca);
#
#
#             var circle_marker_b69947db2b3836e55cccfedcf282bb64 = L.circleMarker(
#                 [42.42698818, -71.06677413],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_0d9ae07eb48af1fb39499303153cbfca);
#
#
#             var circle_marker_ea8dfa9c2a7769a5272e6cecd003d4a2 = L.circleMarker(
#                 [42.4269614, -71.06683507],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_0d9ae07eb48af1fb39499303153cbfca);
#
#
#             var circle_marker_309d78ce006ae94d512d44d58715b64b = L.circleMarker(
#                 [42.42726808, -71.06699094],
#                 {&quot

# %%
malden_places = {
    'Immigrant Learning Center'    : '442 Main Street Malden MA 02148',
    'Malden Public Library'        : '36 Salem St., Malden, MA 02148',    
    'Malden High School'           : '77 Salem St, Malden, MA 02148',
    'Walgreens at Centre and Main' : '185 Centre St, Malden, MA 02148',
    'Centre St & Main St'          : '361 Main St, Malden, MA 02148',
    'Malden City Hall'             : '215 Pleasant St, Malden, MA 02148',
    'Malden Center T Station'      : '30 Commercial St, Malden, MA 02148', # Commercial St &, Pleasant St
    'M&T Bank'                     : '51 Commercial St, Malden, MA 02148',
    'Ferryway School'              : '150 Cross St, Malden, MA 02148',  
    'Salemwood School'             : '529 Salem St, Malden, MA 02148',
    'Beebe School'                 : '401 Pleasant St, Malden, MA 02148',
    'Linden STEAM Academy'         : '29 Wescott St, Malden, MA 02148',
    'Early Learning Center'        : '257 Mountain Ave, Malden, MA 02148',
    'Forestdale School'            : '74 Sylvan Street, Malden, MA 02148',
    'Oak Grove Station'            : '287 Washington St, Malden, MA 02148',
    'Commercial St & Charles St'   : '109 Commercial St, Malden, MA 02148',
    'MA 99 at Broadway Plaza '     : '62 Broadway, Malden, MA 02148',
    'Fellsway & Salem'             : '104 Fellsway W, Medford, MA 02155'
    }

# %%
crash_df = load_data()                

# default address
# address = "442 Main Street Malden MA 02148"

def score_address(data): 
    # make calcuations - box, score
    lat_0 = float(data["lat"])               # don't want to pass around data? too big?
    lon_0 = float(data["lon"])
    min_lat, max_lat, min_lon, max_lon = find_box(lat_0, lon_0)

    # get zone df
    zone_df = get_zone_df(lat_0, lon_0, crash_df);
    count_score = crash_count(zone_df, 2000)
    count_thresh = crash_count(zone_df, 2018) #last 5 years
    walk_score = get_walk_score(lat_0, lon_0)
    return walk_score, count_score, count_thresh # may want to score one by one?

def get_walk_score(lat, lon):
    apikey = '67923e521ee28fd513419b9cb712ea29'
    url = 'http://api.walkscore.com/score?format=json&lat='+str(lat)+'&lon='+str(lon)+'&wsapikey='+apikey
    r = requests.get(url)
    data = r.json()
    return data['walkscore']

# %%
# score a set of addresses
score_df = pd.DataFrame()
score_list = []

col_names = ['location', 'address', 'latitude', 'longitude', 'walk', 'count all', 'count 10 yrs', 'count 5 yrs']

for p in malden_places:
    address = malden_places[p]
    data = geocode(address).json()              # get lon / lat  <--- need to check if valid, check if already have it

    lat_0 = float(data[0]["lat"])               # don't want to pass around data? too big?
    lon_0 = float(data[0]["lon"])
        
    walk = get_walk_score(lat_0, lon_0)    
    
    # get zone df
    min_lat, max_lat, min_lon, max_lon = find_box(lat_0, lon_0)
    zone_df = get_zone_df(lat_0, lon_0, crash_df);

    count_score = crash_count(zone_df, 2000)
    count_10_yrs = crash_count(zone_df, 2013) #last 10 years
    count_5_yrs = crash_count(zone_df, 2018) #last 5 years
        
    score_list.append([p, address, lat_0, lon_0, walk, count_score, count_10_yrs, count_5_yrs])
    
score_df = pd.DataFrame(score_list, columns=col_names)
score_df
# Out:
#                         location                              address  \
# 0      Immigrant Learning Center      442 Main Street Malden MA 02148
# 1          Malden Public Library       36 Salem St., Malden, MA 02148
# 2             Malden High School        77 Salem St, Malden, MA 02148
# 3   Walgreens at Centre and Main      185 Centre St, Malden, MA 02148
# 4            Centre St & Main St        361 Main St, Malden, MA 02148
# 5               Malden City Hall    215 Pleasant St, Malden, MA 02148
# 6        Malden Center T Station   30 Commercial St, Malden, MA 02148
# 7                       M&T Bank   51 Commercial St, Malden, MA 02148
# 8                Ferryway School       150 Cross St, Malden, MA 02148
# 9               Salemwood School       529 Salem St, Malden, MA 02148
# 10                  Beebe School    401 Pleasant St, Malden, MA 02148
# 11          Linden STEAM Academy      29 Wescott St, Malden, MA 02148
# 12         Early Learning Center   257 Mountain Ave, Malden, MA 02148
# 13             Forestdale School   74 Sylvan Street, Malden, MA 02148
# 14             Oak Grove Station  287 Washington St, Malden, MA 02148
# 15    Commercial St & Charles St  109 Commercial St, Malden, MA 02148
# 16      MA 99 at Broadway Plaza         62 Broadway, Malden, MA 02148
# 17              Fellsway & Salem    104 Fellsway W, Medford, MA 02155
#
#      latitude  longitude  walk  count all  count 10 yrs  count 5 yrs
# 0   42.427119 -71.067107    97         10             5            2
# 1   42.427675 -71.066078    97          3             1            1
# 2   42.426765 -71.065067    97          0             0            0
# 3   42.424736 -71.068227    97          0             0            0
# 4   42.425551 -71.067462    98        193            67           19
# 5   42.427348 -71.072732    96          0             0            0
# 6   42.426320 -71.073252    96         19             7            1
# 7   42.425487 -71.074287    96          0             0            0
# 8   42.421591 -71.059460    83          2             2            1
# 9   42.430707 -71.051022    86          0             0            0
# 10  42.427147 -71.079419    87          0             0            0
# 11  42.433811 -71.034458    63          0             0            0
# 12  42.431641 -71.063444    82          0             0            0
# 13  42.440463 -71.053800    24          0             0            0
# 14  42.427565 -71.070657    97          3             3            1
# 15  42.423636 -71.075075    93          0             0            0
# 16  42.424609 -71.042213    83         23            14           10
# 17  42.423989 -71.090535    78         15            10            4

# %%
# Area of Malden: 141.7 million ft²  / 5.081 mi²
# Area of box: 10^9 ft²  (1000 ft)²
# Number of crashes: 18524
# Number of crashes at Centre and Main: 191

num_crashes, features = crash_df.shape
area_Malden = 141.7*10**9
area_zone = 10**9

crash_per_area_Malden = num_crashes/area_Malden
crash_per_area_Malden
# Out:
# 6.875864502470007e-07

# %% [raw]
# avg_zone_crashes = crash_per_area_Malden * area_zone
# avg_zone_crashes

# %%
crash23_df = crash_df[crash_df['Crash Year'] == 2023]

# %%
# map 2023 accidents
start_address = '442 Main Street Malden MA 02148',    # Immigrant Learning Center
lat_0= 42.427119
lon_0 = -71.067107
m23 = folium.Map(location=[lat_0, lon_0], tiles="OpenStreetMap", zoom_start=15)


# Create point geometries
geometry = geopandas.points_from_xy(crash23_df['Latitude'], crash23_df['Longitude'])
geo_df = geopandas.GeoDataFrame(
    crash23_df[["Crash Year", "Latitude", "Longitude", "First Harmful Event"]], geometry=geometry
)

# drop empty points
geo_ok = geo_df.loc[~geo_df.geometry.is_empty]
geometry_ok = geopandas.points_from_xy(geo_ok['Latitude'], geo_ok['Longitude'])


# Create a geometry list from the GeoDataFrame
geo_df_list = [[point.x, point.y] for point in geometry_ok]

for ind, val in enumerate(geo_df_list):
    # Place the markers for car crash
    if geo_df.iloc[ind]['First Harmful Event'] == 'Collision with pedestrian':
        folium.CircleMarker(location=geo_df_list[ind], radius=2, weight=3, color='red').add_to(m23)
    else:
        folium.CircleMarker(location=geo_df_list[ind], radius=2, weight=3, color='blue').add_to(m23)

display(m23)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39e7b6e96c6f0bb017ef998023ea470f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39e7b6e96c6f0bb017ef998023ea470f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39e7b6e96c6f0bb017ef998023ea470f = L.map(
#                 &quot;map_39e7b6e96c6f0bb017ef998023ea470f&quot;,
#                 {
#                     center: [42.427119, -71.067107],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf0a11825657687d1781be4edf775dbb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bf0a11825657687d1781be4edf775dbb.addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_6358255de4fa38c63b16bd3c9280d641 = L.circleMarker(
#                 [42.4064144, -71.10219395],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_f1d7a2ef93478512de3962df5aba1042 = L.circleMarker(
#                 [42.47200362, -71.10946126],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_5340ba91f92b72f5de95113ef0e39e8f = L.circleMarker(
#                 [42.46471613, -71.01251802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_bbbcf2382e1f71181e8b427910c5e803 = L.circleMarker(
#                 [42.45434862, -71.00547894],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_25cf30febdfc7052ceca12f76027e3bf = L.circleMarker(
#                 [42.5023608, -71.11873474],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_4e1dc7814cb465dd4953d2192f9a2e10 = L.circleMarker(
#                 [42.525355, -71.13578944],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39e7b6e96c6f0bb017ef998023ea470f);
#
#
#             var circle_marker_2d508a0329423a8f40674242b6b8d2a7 = L.circleMarker(
#                 [42.41832107, -71.12668862],

# %%
# One degree of latitude equals approximately 364,000 feet (69 miles)
1/364000
# Out:
# 2.747252747252747e-06

# %%
# Degrees = (1 / 5,280 miles) / (69 miles/degree)
1 / 5280 / 69
# Out:
# 2.7448397013614407e-06

# %%
#Degrees = (Distance in miles) / (69 miles/degree)
#Degrees = (1 / 5,280 miles) / (69 miles/degree)
#Degrees ≈ 0.0000165 degrees

# %%
# One-degree of longitude equals 288,200 feet (54.6 miles)
1 / 288200
# Out:
# 3.4698126301179736e-06

# %%
# Degrees of Longitude = (1 / 5,280 miles) / 48.91 miles/degree 
# 0.00001904 degrees

# %% [markdown]
# ## Slider

# %%
crash_df
# Out:
#        Crash Number City Town Name  Crash Date  \
# 0           1531131         MALDEN  01/06/2003
# 1           1534486         MALDEN  01/01/2003
# 2           1534489         MALDEN  01/02/2003
# 3           1534497         MALDEN  01/02/2003
# 4           1534501         MALDEN  01/02/2003
# ...             ...            ...         ...
# 97426       5355825         MALDEN  12/27/2023
# 97427       5355826         MALDEN  12/13/2023
# 97428       5355827         MALDEN  12/13/2023
# 97429       5355828         MALDEN  12/30/2023
# 97430       5355843        MEDFORD  12/22/2023
#
#                             Crash Severity Crash Status Crash Time  \
# 0                             Not Reported       Closed    1:30 PM
# 1                             Not Reported       Closed    4:00 AM
# 2                             Not Reported       Closed    7:00 AM
# 3                         Non-fatal injury       Closed    4:10 AM
# 4                         Non-fatal injury       Closed    2:30 PM
# ...                                    ...          ...        ...
# 97426  Property damage only (none injured)         Open    2:32 PM
# 97427                     Non-fatal injury         Open    9:57 AM
# 97428                              Unknown         Open    8:29 PM
# 97429  Property damage only (none injured)         Open   10:07 PM
# 97430  Property damage only (none injured)         Open   12:30 PM
#
#        Crash Year           Max Injury Severity Reported  Number of Vehicles  \
# 0            2003                           Not reported                   1
# 1            2003                           Not reported                   2
# 2            2003                           Not reported                   2
# 3            2003            Non-fatal injury - Possible                   3
# 4            2003  Non-fatal injury - Non-incapacitating                   2
# ...           ...                                    ...                 ...
# 97426        2023                 No Apparent Injury (O)                   2
# 97427        2023                    Possible Injury (C)                   2
# 97428        2023                           Not reported                   1
# 97429        2023                 No Apparent Injury (O)                   3
# 97430        2023                 No Apparent Injury (O)                   5
#
#       Police Agency Type  ... Terrain-linked RD  \
# 0           Local police  ...               NaN
# 1           Local police  ...             Level
# 2           Local police  ...             Level
# 3           Local police  ...             Level
# 4           Local police  ...             Level
# ...                  ...  ...               ...
# 97426       Local police  ...     Level Terrain
# 97427       Local police  ...     Level Terrain
# 97428       Local police  ...     Level Terrain
# 97429       Local police  ...     Level Terrain
# 97430       State police  ...               NaN
#
#                            Urban Location Type-linked RD  \
# 0                                                    NaN
# 1      Not applicable (i.e., not a principal arterial...
# 2      High density business/commercial center (exclu...
# 3      High density residential (5,000 or more person...
# 4                                 Low density commercial
# ...                                                  ...
# 97426                                                NaN
# 97427                                                NaN
# 97428                                                NaN
# 97429                                                NaN
# 97430                                                NaN
#
#                 AADT Derivation-linked RD AADT Station Number-linked RD  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
# ...                                   ...                           ...
# 97426  Grown from Prior Year HPMS Network                           NaN
# 97427                                 NaN                           NaN
# 97428                                 NaN                           NaN
# 97429  Grown from Prior Year HPMS Network                           NaN
# 97430                                 NaN                           NaN
#
#       Opposing Direction Speed Limit-linked RD  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 97426                                     20.0
# 97427                                      NaN
# 97428                                      NaN
# 97429                                     20.0
# 97430                                      NaN
#
#       Undivided Left Shoulder Type-linked RD  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 97426                                      0
# 97427                                      0
# 97428                                      0
# 97429                                      0
# 97430                                    NaN
#
#       Undivided Left Shoulder Width-linked RD  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 97426                                     0.0
# 97427                                     0.0
# 97428                                     0.0
# 97429                                     0.0
# 97430                                     NaN
#
#             Truck Exclusion Type-linked RD Truck Exclusion Time-linked RD  \
# 0                                      NaN                            NaN
# 1                                      NaN                            NaN
# 2                                      NaN                            NaN
# 3                                      NaN                            NaN
# 4                                      NaN                            NaN
# ...                                    ...                            ...
# 97426  All vehicles over 2.5 tons excluded               24 Hours, 7 Days
# 97427                                  NaN                            NaN
# 97428                                  NaN                            NaN
# 97429                                  NaN                            NaN
# 97430                                  NaN                            NaN
#
#       Federal Functional Classification-linked RD
# 0                                             NaN
# 1                      Principal Arterial - Other
# 2                      Principal Arterial - Other
# 3                                  Minor Arterial
# 4                      Principal Arterial - Other
# ...                                           ...
# 97426                              Minor Arterial
# 97427                                       Local
# 97428                                       Local
# 97429                              Minor Arterial
# 97430                                         NaN
#
# [97431 rows x 123 columns]

# %%
from ipywidgets import interactive
from matplotlib import cm

# %matplotlib inline      

crash = malden_df.sort_values('Crash Year', ascending=True)
min_year = 2013
max_year = 2023
num_years = 11
years_range = np.linspace(min_year, max_year, num_years)

cmap = plt.get_cmap('viridis_r')
norm = plt.Normalize(min_year, max_year)

colors = cmap(norm(200.))
color_list = cm.viridis_r(np.linspace(0, 1, num_years))
color_dict = dict(zip(years_range, color_list))

def f(Year):
    plt.figure(figsize=(7, 4))

    x = crash.loc[crash['Crash Year'] == Year, 'Latitude']
    y = crash.loc[crash['Crash Year'] == Year, 'Longitude']

    xp = ped_crash.loc[ped_crash['Crash Year'] == Year, 'Latitude']
    yp = ped_crash.loc[ped_crash['Crash Year'] == Year, 'Longitude']

    xf = ped_fatal.loc[ped_fatal['Crash Year'] == Year, 'Latitude']
    yf = ped_fatal.loc[ped_fatal['Crash Year'] == Year, 'Longitude']

    plt.xlabel('Latitude')
    plt.ylabel('Longitude')
    plt.title('Car crashes in Malden by Year: ' + str(int(Year)))
    
    plt.xlim(42.413, 42.445)
    plt.ylim(-71.091, -71.015)

    plt.plot(x, y, '.', c=color_dict[Year])         
    plt.plot(xp, yp, 'ob', xf, yf, 'or')         

    plt.legend(['crash', 'pedestrian accident', 'pedestrian death'], loc='upper left')
    
    plt.xticks(rotation = 45)   
    plt.show()

interactive_plot = interactive(f, Year=(2013, 2023))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=2018, description='Year', max=2023, min=2013), Output()), _dom_classes=(…
